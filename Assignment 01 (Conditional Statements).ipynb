# %% [markdown]
# 1) A company decided to give bonus of 5% to employee if his/her year of service is more than 5 years.
# Ask user for their salary and year of service and print the net bonus amount.

# %%
salary=int(input("enter salary"))
years=int(input("enter years of service"))
if  years >5:
    bonus=salary * 5/100
    print(bonus)
else:
    print("no bonus")#salary= 50000 taken , years = 6 taken
# Out:
# 2500.0

# %% [markdown]
# 2) Write a program to check whether a person is eligible for voting or not. (accept age from user) if age is greater than 17 eligible otherwise not eligible

# %%
age=int(input("enter your age"))
if age>=17:
    print("your are eligible for voting")
else:
    print("you are not eligible for voting")#age = 17 taken
# Out:
# your are eligible for voting

# %% [markdown]
# 3) Write a program to check whether a number entered by user is even or odd.

# %%
num=int(input("enter your number"))
if num % 2 == 0:
   print("it is even")
else:
    print("it is odd")#num = 5 taken
# Out:
# it is odd

# %% [markdown]
# 4) Write a program to check whether a number is divisible by 7 or not.
# Show Answer

# %%
num=int(input("enter a num"))
if num % 7 == 0:
    print("number is divisble by 7")
else:
    print("number is not divisible by 7") #num = 5 taken
# Out:
# number is not divisible by 7

# %% [markdown]
# 5) Write a program to display
# "Hello" if a number entered by user is a multiple of five , otherwise print "Bye".

# %%
num=int(input("enter a num"))
if num % 5 == 0:
    print("hello")
else:
    print("bye")#num = 6 taken
# Out:
# bye

# %% [markdown]
# 6. Take values of length and breadth of a rectangle from user and print if it is square or rectangle.

# %%
length=float(input("enter the length of rectangle"))
breadth=float(input("enter the breadth of rectangle"))
if length == breadth:
    print("it is square")
else:
    print("it is rectangle")#length = 5 taken , breadth = 5 taken
# Out:
# it is square

# %% [markdown]
# 7. Take two int values from user and print greatest among them.

# %%
num1=int(input("enter a num"))#6
num2=int(input("enter a num"))#5
if num1 > num2:
    print("it is greatest")
else:
    print("it is not greatest")
# Out:
# it is greatest

# %% [markdown]
# 8. A school has following rules for grading system:
#
# a. Below 25 - F
#
# b. 25 to 45 - E
#
# c. 45 to 50 - D
#
# d. 50 to 60 - C
#
# e. 60 to 80 - B
#
# f. Above 80 - A
#
# Ask user to enter marks and print the corresponding grade.

# %%
marks=int(input("input you marks"))#marks= 85 taken
if marks>=0 and marks<25:
    print(f"your marks is {marks} and your grade is F")
elif marks>=25 and marks<45:
    print(f"your marks is {marks} and your grade is E")
elif marks>=45 and marks<50:
    print(f"your marks is {marks} and your grade is D")
elif marks>=50 and marks<60:
    print(f"your marks is {marks} and your grade is C")
elif marks>=60 and marks<80:
    print(f"your marks is {marks} and your grade is B")
elif marks>=80 and marks<100:
    print(f"your marks is {marks}  and grade is A")
else:
    print(f"you put an invalid number")
# Out:
# your marks is 85  and grade is A

# %% [markdown]
# 9. Ask user to enter age, gender ( M or F ), marital status ( Y or N ) and then using following rules print their place of service.
#
# if employee is female, then she will work only in urban areas.
#
# if employee is a male and age is in between 20 to 40 then he may work in anywhere
#
# if employee is male and age is in between 40 t0 60 then he will work in urban areas only.
#
# And any other input of age should print "ERROR"

# %%
age=int(input("enter the age "))#AGE = 25 TAKEN
gender=input("enter your gender (M/F):")# M TAKEN
matrial=input("enter the matrial status (Y/N):")# N TAKEN
if gender == "F":
    print("she will work only in urban areas")
elif gender == "M":
    if age>=20 and age<=40:
        print("he work in anywhere")
    elif age>=40 and age<=60:
        print("he will work in urban areas only")
    else:
        print("error: invalid age ")
else:
    print("error:invalid gender")
# Out:
# he work in anywhere
